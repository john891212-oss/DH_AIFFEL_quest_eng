# %%
import sansu
sansu.run()
# Out:
# ==== 계산기 시작 ====
# 정수를 입력하세요. :  5
# 오른쪽의 연산자 중 하나만 고르시오. (+, -, *, /, **):  /
# 다음 정수를 입력하세요 :  0
# 나눌 때'0'좀 넣지마라.
# 계속 계산할까요? (yes / no):  yes
# 정수를 입력하세요. :  1
# 오른쪽의 연산자 중 하나만 고르시오. (+, -, *, /, **):  +
# 다음 정수를 입력하세요 :  5
# 결과: 1 + 5 = 6
# 계속 계산할까요? (yes / no):  yes
# 정수를 입력하세요. :  1
# 오른쪽의 연산자 중 하나만 고르시오. (+, -, *, /, **):  5
# 다음 정수를 입력하세요 :  1
# 오류: '5'가 보기 안에 있던 연산자 입니까?
# 계속 계산할까요? (yes / no):  yes
# 정수를 입력하세요. :  a
# 정수를 입력하라고요, 정수를
# 정수를 입력하세요. :  5
# 오른쪽의 연산자 중 하나만 고르시오. (+, -, *, /, **):  +
# 다음 정수를 입력하세요 :  a
# 정수만 입력 받습니다.
# 정수를 입력하세요. :  5
# 오른쪽의 연산자 중 하나만 고르시오. (+, -, *, /, **):  a
# 다음 정수를 입력하세요 :  1
# 오류: 'a'가 보기 안에 있던 연산자 입니까?
